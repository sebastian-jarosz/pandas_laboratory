# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastian-jarosz/pandas_laboratory/blob/main/Uczenie_Maszynowe_Lab_Cw5_Jarosz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/palles77/MachineLearning_Exercise4/main/Employee_Compensation_SF.csv')

# %%
# function returning column index in a dataframe
def column_index(df, query_cols):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols,query_cols,sorter=sidx)]

# %%
# reading 'Total Benefits' -> column 20, 'Total Compensation' -> column 21
(column_first, colum_second) = column_index(dataset, ['Total Benefits', 'Total Compensation'])
# get sample 1000 rows
dataset_for_clustering = dataset.sample(1000).iloc[:, [column_first, colum_second]].values

# %%
# Drawing dendrogram
dendrogram = sch.dendrogram(sch.linkage(dataset_for_clustering, method='ward'))

# %%
# X was missing in agglomerative_clustering.ipynb
X = dataset_for_clustering

model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='ward')
model.fit(X)
labels = model.labels_

# %%
# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

# %%
# 1. Przeprowadzić klasteryzację dla par kolumn 'Total Salary', 'Retirement'
# reading 'Total Benefits' -> column 20, 'Total Compensation' -> column 21
(column_first, colum_second) = column_index(dataset, ['Total Salary', 'Retirement'])
# get sample 1000 rows
dataset_for_clustering2 = dataset.sample(1000).iloc[:, [column_first, colum_second]].values

# 2. Pokazać wynik klasteryzacji w postaci dendrogramów dla poniższych typów linkage: 'ward', 'complete', 'average', 'single'.
# Drawing dendrogram
print('--- ward ---')
dendrogram1 = sch.dendrogram(sch.linkage(dataset_for_clustering, method='ward'))
plt.show()
print('--- complete ---')
dendrogram2 = sch.dendrogram(sch.linkage(dataset_for_clustering, method='complete'))
plt.show()
print('--- average ---')
dendrogram3 = sch.dendrogram(sch.linkage(dataset_for_clustering, method='average'))
plt.show()
print('--- single ---')
dendrogram4 = sch.dendrogram(sch.linkage(dataset_for_clustering, method='single'))
plt.show()
# Out:
# --- ward ---
# --- complete ---
# --- average ---
# --- single ---

# %%
# 3. Dla każdego z dendrogramów wybrać wizualnie liczbę klastrów i pokazać ich ułożenie w sposób podobny
X = dataset_for_clustering2

print('--- ward ---')
model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='ward')
model.fit(X)
labels = model.labels_

# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

print('--- complete ---')
model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='complete')
model.fit(X)
labels = model.labels_

# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

print('--- average ---')
model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='average')
model.fit(X)
labels = model.labels_

# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()

print('--- single ---')
model = AgglomerativeClustering(n_clusters = 3, affinity='euclidean', linkage='single')
model.fit(X)
labels = model.labels_

# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
# plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
# plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
#plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
#plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.xlabel('Total Benefits')
plt.ylabel('Total Compensation')
plt.show()
# Out:
# --- ward ---
# --- complete ---
# --- average ---
# --- single ---
